# %%
# %load_ext autoreload
# %autoreload 2

# %%
from after.autoencoder.networks.SimpleNet2D import AutoEncoder2D

import gin

# %%
config = "AE_64_realtime.gin"

# %%
gin.clear_config()
gin.parse_config_file(config)
model = AutoEncoder2D().eval()
