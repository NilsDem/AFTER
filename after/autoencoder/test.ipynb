# %%
from audio import CausalMauerSTFT
import matplotlib.pyplot as plt


stft = CausalMauerSTFT(nfft=1024, hop_size=512, zero_length=0, synthesis_length = 1024 )

plt.figure(figsize=(12, 4))
plt.plot(stft.analysis_window.cpu(), label="Analysis")
plt.plot(stft.synthesis_window.cpu(), label="Synthesis")
plt.legend()
plt.show()
